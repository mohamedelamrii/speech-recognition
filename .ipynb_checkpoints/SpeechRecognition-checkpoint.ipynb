# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings

warnings.filterwarnings("ignore")

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda3\lib\site-packages (2.9.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
#
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in d:\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in d:\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in d:\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in d:\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.9.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)

# %%
import tensorflow as tf

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'link_to_gcp_credits_form.txt',
#  'sample_submission.csv',
#  'SpeechRecognition.ipynb',
#  'test',
#  'train']

# %%
train_audio_path = './train/audio/'
samples, sample_rate = librosa.load(train_audio_path+'yes/004ae714_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + './train/audio/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample_rate)
# Out:
# 16000

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)

# %%
#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
labels=["no", "off", "on", "right", "left", "bed", "bird", "cat", "dog", "down", "five", "four", "go", "happy", "house", "yes", "zero", "stop"]

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.8000e+01, 4.8000e+01, 7.2000e+01, 2.0600e+02, 2.1400e+02,
#         2.8900e+02, 5.6900e+02, 7.2000e+02, 9.9800e+02, 3.5693e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <BarContainer object of 10 artists>)

# %%
train_audio_path = './train/audio/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# no
# off
# on
# right
# left
# bed
# bird
# cat
# dog
# down
# five
# four
# go
# happy
# house
# yes
# zero
# stop

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13064/4033135915.py in <module>
#       2 le = LabelEncoder()
#       3
# ----> 4 classes= list(le.classes_)
#
# AttributeError: 'LabelEncoder' object has no attribute 'classes_'

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

inputs = Input(shape=(8000,1))

#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.3)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.3)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8000, 1)]         0
#
#  conv1d (Conv1D)             (None, 7988, 8)           112
#
#  max_pooling1d (MaxPooling1D  (None, 2662, 8)          0
#  )
#
#  dropout (Dropout)           (None, 2662, 8)           0
#
#  conv1d_1 (Conv1D)           (None, 2652, 16)          1424
#
#  max_pooling1d_1 (MaxPooling  (None, 884, 16)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 884, 16)           0
#
#  conv1d_2 (Conv1D)           (None, 876, 32)           4640
#
#  max_pooling1d_2 (MaxPooling  (None, 292, 32)          0
#  1D)
#
#  dropout_2 (Dropout)         (None, 292, 32)           0
#
#  conv1d_3 (Conv1D)           (None, 286, 64)           14400
#
#  max_pooling1d_3 (MaxPooling  (None, 95, 64)           0
#  1D)
#
#  dropout_3 (Dropout)         (None, 95, 64)            0
#
#  flatten (Flatten)           (None, 6080)              0
#
#  dense (Dense)               (None, 256)               1556736
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 18)                2322
#
# =================================================================
# Total params: 1,612,530
# Trainable params: 1,612,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model1.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_tr, y_tr ,epochs=100, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 874/874 [==============================] - ETA: 0s - loss: 2.5945 - accuracy: 0.1586
# Epoch 1: val_accuracy improved from -inf to 0.35508, saving model to best_model1.hdf5
# 874/874 [==============================] - 278s 308ms/step - loss: 2.5945 - accuracy: 0.1586 - val_loss: 1.9533 - val_accuracy: 0.3551
# Epoch 2/100
# 874/874 [==============================] - ETA: 0s - loss: 1.9107 - accuracy: 0.3713
# Epoch 2: val_accuracy improved from 0.35508 to 0.49943, saving model to best_model1.hdf5
# 874/874 [==============================] - 263s 301ms/step - loss: 1.9107 - accuracy: 0.3713 - val_loss: 1.5220 - val_accuracy: 0.4994
# Epoch 3/100
# 874/874 [==============================] - ETA: 0s - loss: 1.6508 - accuracy: 0.4583
# Epoch 3: val_accuracy improved from 0.49943 to 0.51760, saving model to best_model1.hdf5
# 874/874 [==============================] - 262s 300ms/step - loss: 1.6508 - accuracy: 0.4583 - val_loss: 1.4504 - val_accuracy: 0.5176
# Epoch 4/100
# 874/874 [==============================] - ETA: 0s - loss: 1.5239 - accuracy: 0.4947
# Epoch 4: val_accuracy improved from 0.51760 to 0.56795, saving model to best_model1.hdf5
# 874/874 [==============================] - 260s 298ms/step - loss: 1.5239 - accuracy: 0.4947 - val_loss: 1.3470 - val_accuracy: 0.5680
# Epoch 5/100
# 874/874 [==============================] - ETA: 0s - loss: 1.4295 - accuracy: 0.5249
# Epoch 5: val_accuracy improved from 0.56795 to 0.60186, saving model to best_model1.hdf5
# 874/874 [==============================] - 266s 304ms/step - loss: 1.4295 - accuracy: 0.5249 - val_loss: 1.2735 - val_accuracy: 0.6019
# Epoch 6/100
# 874/874 [==============================] - ETA: 0s - loss: 1.3386 - accuracy: 0.5567
# Epoch 6: val_accuracy improved from 0.60186 to 0.63534, saving model to best_model1.hdf5
# 874/874 [==============================] - 262s 300ms/step - loss: 1.3386 - accuracy: 0.5567 - val_loss: 1.1132 - val_accuracy: 0.6353
# Epoch 7/100
# 874/874 [==============================] - ETA: 0s - loss: 1.2397 - accuracy: 0.5929
# Epoch 7: val_accuracy improved from 0.63534 to 0.65093, saving model to best_model1.hdf5
# 874/874 [==============================] - 267s 305ms/step - loss: 1.2397 - accuracy: 0.5929 - val_loss: 1.0936 - val_accuracy: 0.6509
# Epoch 8/100
# 874/874 [==============================] - ETA: 0s - loss: 1.1612 - accuracy: 0.6188
# Epoch 8: val_accuracy improved from 0.65093 to 0.68526, saving model to best_model1.hdf5
# 874/874 [==============================] - 265s 303ms/step - loss: 1.1612 - accuracy: 0.6188 - val_loss: 0.9904 - val_accuracy: 0.6853
# Epoch 9/100
# 874/874 [==============================] - ETA: 0s - loss: 1.0708 - accuracy: 0.6505
# Epoch 9: val_accuracy improved from 0.68526 to 0.74235, saving model to best_model1.hdf5
# 874/874 [==============================] - 274s 313ms/step - loss: 1.0708 - accuracy: 0.6505 - val_loss: 0.8211 - val_accuracy: 0.7423
# Epoch 10/100
# 874/874 [==============================] - ETA: 0s - loss: 0.9789 - accuracy: 0.6823
# Epoch 10: val_accuracy improved from 0.74235 to 0.75165, saving model to best_model1.hdf5
# 874/874 [==============================] - 268s 307ms/step - loss: 0.9789 - accuracy: 0.6823 - val_loss: 0.7961 - val_accuracy: 0.7516
# Epoch 11/100
# 874/874 [==============================] - ETA: 0s - loss: 0.9164 - accuracy: 0.7041
# Epoch 11: val_accuracy improved from 0.75165 to 0.76481, saving model to best_model1.hdf5
# 874/874 [==============================] - 264s 302ms/step - loss: 0.9164 - accuracy: 0.7041 - val_loss: 0.7400 - val_accuracy: 0.7648
# Epoch 12/100
# 874/874 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.7154
# Epoch 12: val_accuracy improved from 0.76481 to 0.78183, saving model to best_model1.hdf5
# Epoch 32/100
# 874/874 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8358
# Epoch 32: val_accuracy did not improve from 0.85050
# 874/874 [==============================] - 261s 299ms/step - loss: 0.5157 - accuracy: 0.8358 - val_loss: 0.5017 - val_accuracy: 0.8465
# Epoch 33/100
# 874/874 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.8379
# Epoch 33: val_accuracy did not improve from 0.85050
# 874/874 [==============================] - 263s 300ms/step - loss: 0.5090 - accuracy: 0.8379 - val_loss: 0.5072 - val_accuracy: 0.8423
# Epoch 34/100
# 874/874 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.8361
# Epoch 34: val_accuracy did not improve from 0.85050
# 874/874 [==============================] - 264s 301ms/step - loss: 0.5117 - accuracy: 0.8361 - val_loss: 0.5028 - val_accuracy: 0.8412
# Epoch 35/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.8408
# Epoch 35: val_accuracy did not improve from 0.85050
# 874/874 [==============================] - 269s 308ms/step - loss: 0.4930 - accuracy: 0.8408 - val_loss: 0.5036 - val_accuracy: 0.8436
# Epoch 36/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4846 - accuracy: 0.8437
# Epoch 36: val_accuracy did not improve from 0.85050
# 874/874 [==============================] - 266s 304ms/step - loss: 0.4846 - accuracy: 0.8437 - val_loss: 0.4924 - val_accuracy: 0.8472
# Epoch 37/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8462
# Epoch 37: val_accuracy improved from 0.85050 to 0.85694, saving model to best_model1.hdf5
# 874/874 [==============================] - 266s 305ms/step - loss: 0.4803 - accuracy: 0.8462 - val_loss: 0.4690 - val_accuracy: 0.8569
# Epoch 38/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8458
# Epoch 38: val_accuracy did not improve from 0.85694
# 874/874 [==============================] - 265s 303ms/step - loss: 0.4739 - accuracy: 0.8458 - val_loss: 0.4746 - val_accuracy: 0.8535
# Epoch 39/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8472
# Epoch 39: val_accuracy did not improve from 0.85694
# 874/874 [==============================] - 263s 301ms/step - loss: 0.4759 - accuracy: 0.8472 - val_loss: 0.5235 - val_accuracy: 0.8415
# Epoch 40/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.8520
# Epoch 40: val_accuracy did not improve from 0.85694
# 874/874 [==============================] - 266s 304ms/step - loss: 0.4601 - accuracy: 0.8520 - val_loss: 0.4916 - val_accuracy: 0.8509
# Epoch 41/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.8546
# Epoch 41: val_accuracy improved from 0.85694 to 0.85994, saving model to best_model1.hdf5
# 874/874 [==============================] - 265s 303ms/step - loss: 0.4524 - accuracy: 0.8546 - val_loss: 0.4644 - val_accuracy: 0.8599
# Epoch 42/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8558
# Epoch 42: val_accuracy did not improve from 0.85994
# 874/874 [==============================] - 260s 297ms/step - loss: 0.4479 - accuracy: 0.8558 - val_loss: 0.4807 - val_accuracy: 0.8554
# Epoch 43/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8604
# Epoch 43: val_accuracy did not improve from 0.85994
# 874/874 [==============================] - 256s 293ms/step - loss: 0.4417 - accuracy: 0.8604 - val_loss: 0.4769 - val_accuracy: 0.8554
# Epoch 44/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.8545
# Epoch 44: val_accuracy improved from 0.85994 to 0.86023, saving model to best_model1.hdf5
# 874/874 [==============================] - 257s 294ms/step - loss: 0.4524 - accuracy: 0.8545 - val_loss: 0.4643 - val_accuracy: 0.8602
# Epoch 45/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8586
# Epoch 45: val_accuracy did not improve from 0.86023
# 874/874 [==============================] - 258s 295ms/step - loss: 0.4408 - accuracy: 0.8586 - val_loss: 0.5234 - val_accuracy: 0.8402
# Epoch 46/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.8604
# Epoch 46: val_accuracy did not improve from 0.86023
# 874/874 [==============================] - 258s 295ms/step - loss: 0.4348 - accuracy: 0.8604 - val_loss: 0.4685 - val_accuracy: 0.8591
# Epoch 47/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8616
# Epoch 47: val_accuracy did not improve from 0.86023
# 874/874 [==============================] - 258s 295ms/step - loss: 0.4278 - accuracy: 0.8616 - val_loss: 0.5019 - val_accuracy: 0.8491
# Epoch 48/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.8630
# Epoch 48: val_accuracy did not improve from 0.86023
# 874/874 [==============================] - 4374s 5s/step - loss: 0.4307 - accuracy: 0.8630 - val_loss: 0.5075 - val_accuracy: 0.8454
# Epoch 49/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8651
# Epoch 49: val_accuracy improved from 0.86023 to 0.86037, saving model to best_model1.hdf5
# 874/874 [==============================] - 260s 297ms/step - loss: 0.4219 - accuracy: 0.8651 - val_loss: 0.4604 - val_accuracy: 0.8604
# Epoch 50/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.8650
# Epoch 50: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 264s 302ms/step - loss: 0.4179 - accuracy: 0.8650 - val_loss: 0.4957 - val_accuracy: 0.8492
# Epoch 51/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8619
# Epoch 51: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 254s 290ms/step - loss: 0.4278 - accuracy: 0.8619 - val_loss: 0.5424 - val_accuracy: 0.8361
# Epoch 52/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8700
# Epoch 52: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 263s 301ms/step - loss: 0.4102 - accuracy: 0.8700 - val_loss: 0.4993 - val_accuracy: 0.8506
# Epoch 53/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4233 - accuracy: 0.8665
# Epoch 53: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 269s 308ms/step - loss: 0.4233 - accuracy: 0.8665 - val_loss: 0.4812 - val_accuracy: 0.8551
# Epoch 54/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8705
# Epoch 54: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 259s 297ms/step - loss: 0.4034 - accuracy: 0.8705 - val_loss: 0.4784 - val_accuracy: 0.8554
# Epoch 55/100
# 874/874 [==============================] - ETA: 0s - loss: 0.3992 - accuracy: 0.8708
# Epoch 55: val_accuracy did not improve from 0.86037
# 874/874 [==============================] - 249s 285ms/step - loss: 0.3992 - accuracy: 0.8708 - val_loss: 0.4908 - val_accuracy: 0.8501
# Epoch 56/100
# 874/874 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.8696
# Epoch 56: val_accuracy improved from 0.86037 to 0.86080, saving model to best_model1.hdf5
# 874/874 [==============================] - 247s 283ms/step - loss: 0.4051 - accuracy: 0.8696 - val_loss: 0.4632 - val_accuracy: 0.8608
# Epoch 57/100
# 874/874 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8755
# Epoch 57: val_accuracy did not improve from 0.86080
# 874/874 [==============================] - 245s 281ms/step - loss: 0.3901 - accuracy: 0.8755 - val_loss: 0.4810 - val_accuracy: 0.8544
# Epoch 58/100
# 874/874 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8741
# Epoch 58: val_accuracy did not improve from 0.86080
# 874/874 [==============================] - 244s 280ms/step - loss: 0.3965 - accuracy: 0.8741 - val_loss: 0.4887 - val_accuracy: 0.8526
# Epoch 59/100
# 874/874 [==============================] - ETA: 0s - loss: 0.3811 - accuracy: 0.8782
# Epoch 59: val_accuracy did not improve from 0.86080
# 874/874 [==============================] - 245s 280ms/step - loss: 0.3811 - accuracy: 0.8782 - val_loss: 0.5306 - val_accuracy: 0.8375
# Epoch 59: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from keras.models import load_model
model=load_model('best_model1.hdf5')

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return labels[index]

# %%
samples, sample_rate = librosa.load('./test/audio/clip_8a2a1b1e3.wav', sr=16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Text:",predict(samples))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Text: left

# %%
pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in d:\anaconda3\lib\site-packages (0.4.4)
# Requirement already satisfied: CFFI>=1.0 in d:\anaconda3\lib\site-packages (from sounddevice) (1.14.6)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # seconds
filename = 'no.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# end

# %%
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
samples, sample_rate = librosa.load(filename, sr=16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
print("Text:",predict(samples))
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Text: left

# %%
os.listdir('../input/voice-commands/prateek_voice_v2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8732/927147607.py in <module>
# ----> 1 os.listdir('../input/voice-commands/prateek_voice_v2')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../input/voice-commands/prateek_voice_v2'

# %%
filepath='../input/voice-commands/prateek_voice_v2'

# %%
#reading the voice commands
samples, sample_rate = librosa.load(filepath + '/' + 'stop.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)

# %%
#converting voice commands to text
predict(samples)
